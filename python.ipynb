# %%
print('welcome')
# Out:
# welcome

# %%
word = input("Please enter a word: ")
print(word)
# Out:
# Please enter a word: hello
# hello

# %%
mess=input("Enter the message: ")
print(mess)
# Out:
# Enter the message: hi
# hi

# %%
a=int(input("Enter the integer: "))
print(a)
# Out:
# Enter the integer: 74
# 74

# %%
frac_no=float(input())
print(frac_no)
# Out:
# 45.7
# 45.7

# %%
num=float(input())
print("{:.2f}".format(num))
# Out:
# 452.5
# 452.50

# %%
num = 255
print(hex(num),oct(num))
# Out:
# 0xff 0o377

# %%
hex_num = input()
print(int(hex_num, 16))
# Out:
# 4
# 4

# %%
ch = input()
print(ord(ch))
# Out:
# m
# 109

# %%
ascii_value = 48

print(chr(ascii_value))
# Out:
# 0

# %%
a = 10
b = 20
print(a, b)
# Out:
# 10 20

# %%
a = 10
b = 20
print(a, "\t", b)
# Out:
# 10 	 20

# %%
ch = 'A'
print("'" + ch + "'")
# Out:
# 'A'

# %%
print("\"Hello\" \"World\"")
# Out:
# "Hello" "World"

# %%
day = input("Enter day: ")
month = input("Enter month: ")
year = input("Enter year: ")

print(day + "/" + month + "/" + year)
# Out:
# Enter day: 12
# Enter month: may
# Enter year: 2030
# 12/may/2030

# %%
a=int(input("enter number: "))
print("+",a)
# Out:
# enter number: 4
# + 4

# %%
import sys
# sys.getsizeof function is used to retrieve the size of each variable.
ch = 'A'
num = 10
f = 10.5
d = 20.56789

print("Size of char:", sys.getsizeof(ch))
print("Size of int:", sys.getsizeof(num))
print("Size of float:", sys.getsizeof(f))
print("Size of double:", sys.getsizeof(d))
# Out:
# Size of char: 42
# Size of int: 28
# Size of float: 24
# Size of double: 24

# %%
roll_no = int(input())
name = input()

print("Roll No:", roll_no, ", Name:", name)
# Out:
# 12
# moni
# Roll No: 12 , Name: moni

# %%
print("English : 47")
print("Maths   : 90")
print("Science : 58")
print("Social  : 48")
print("Tamil   : 92")
# Out:
# English : 47
# Maths   : 90
# Science : 58
# Social  : 48
# Tamil   : 92

# %%
blood_group = input("Enter your blood group: ")
print("Your blood group is:", blood_group)
# Out:
# Enter your blood group: AB
# Your blood group is: AB

# %%
from datetime import datetime

current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
# Out:
# 04:09:23

# %%
from datetime import datetime

current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
# Out:
# 04:09:15

# %%
print("KCE,\ncoimbatore\nTamil Nadu\nIndia")
# Out:
# KCE,
# coimbatore
# Tamil Nadu
# India

# %%
a=int(input())
b=int(input())
print("addition of 2 numbers:",a+b)
print("Difference of 2 numbers:",a-b)
print("product of 2 numbers:",a*b)
print("remainder of 2 numbers:",a%b)
print("quotient of 2 numbers:",a//b)
# Out:
# 34
# 43
# addition of 2 numbers: 77
# Difference of 2 numbers: -9
# product of 2 numbers: 1462
# remainder of 2 numbers: 34
# quotient of 2 numbers: 0

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

temp = a
a = b
b = temp

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 10
# Enter second number: 5
# After swapping:
# a = 5
# b = 10

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a = a + b
b = a - b
a = a - b

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 5
# Enter second number: 6
# After swapping:
# a = 6
# b = 5

# %%
#print the last digit of given number N
N = int(input("Enter a number: "))
last_digit = N % 10
print("Last digit of", N, "is", last_digit)
# Out:
# Enter a number: 47
# Last digit of 47 is 7

# %%
# print the all digits Except last digit of given number N
N = int(input("Enter a number: "))
digits = N // 10
print("All digits of", N, "except last digit:", digits)
# Out:
# Enter a number: 541238
# All digits of 541238 except last digit: 54123

# %%
# print the middle digit of a 3-digit number.
N = int(input("Enter a 3-digit number: "))
middle_digit = (N % 100) // 10
print("Middle digit of", N, "is", middle_digit)
# Out:
# Enter a 3-digit number: 123
# Middle digit of 123 is 2

# %%
# print the absolute value of a given number.
N = int(input("Enter a number: "))
absolute_value = abs(N)
print("Absolute value of", N, "is", absolute_value)
# Out:
# Enter a number: 78954
# Absolute value of 78954 is 78954

# %%
# print the square of a given number
N = int(input("Enter a number: "))
square = N ** 2
print("Square of", N, "is", square)
# Out:
# Enter a number: 3
# Square of 3 is 9

# %%
# print the cube of a given number
N = int(input("Enter a number: "))
cube = N ** 3
print("Cube of", N, "is", cube)
# Out:
# Enter a number: 4
# Cube of 4 is 64

# %%
#average of three numbers
a=int(input())
b=int(input())
c=int(input())
print(a+b+c/3)
# Out:
# 4
# 7
# 9
# 14.0

# %%
a=int(input())
b=int(input())
if a==b:
  print("equal")
else:
  print("not equal")
